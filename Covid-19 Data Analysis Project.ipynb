# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
# %matplotlib inline
import plotly
import plotly.express as px
from plotly.offline import iplot
import plotly.graph_objects as go
import plotly.offline as pyo
import cufflinks as cf
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
plt.rcParams['figure.figsize']=17,8
import folium

pyo.init_notebook_mode(connected=True)
cf.go_offline()
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-19-fc4b2d6ab9ef> in <module>
#       9 import plotly.graph_objects as go
#      10 import plotly.offline as pyo
# ---> 11 import cufflinks as cf
#      12 from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
#      13 plt.rcParams['figure.figsize']=17,8
#
# F:\tutorials\anacondaa\lib\site-packages\cufflinks\__init__.py in <module>
#      13 from . import datagen
#      14 from . import helper
# ---> 15 from . import tools
#      16 from . import colors
#      17 from . import pandastools
#
# F:\tutorials\anacondaa\lib\site-packages\cufflinks\tools.py in <module>
#       4 import pandas as pd
#       5 import plotly.offline as py_offline
# ----> 6 import plotly.plotly as py
#       7 import plotly.graph_objs as go
#       8
#
# ...

# %%
conda install -c conda-forge/label/gcc7 cufflinks-py
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: F:\tutorials\anacondaa
#
#   added / updated specs:
#     - cufflinks-py
#
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates     pkgs/main::ca-certificates-2020.1.1-0 --> conda-forge/label/gcc7::ca-certificates-2018.10.15-ha4d7672_0
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c plotly plotly=4.3.0
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: F:\tutorials\anacondaa
#
#   added / updated specs:
#     - plotly=4.3.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     plotly-4.3.0               |             py_0         4.1 MB  plotly
#     ------------------------------------------------------------
#                                            Total:         4.1 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    conda-forge/label/gcc7::ca-certificat~ --> pkgs/main::ca-certificates-2020.1.1-0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   plotly                       pkgs/main::plotly-4.6.0-py_0 --> plotly::plotly-4.3.0-py_0
#
#
#
# ...
#
# plotly-4.3.0         | 4.1 MB    |            |   0%
# plotly-4.3.0         | 4.1 MB    |            |   0%
# ...

# %%
df=pd.read_excel(r"C:\Users\dell\Desktop\Data Analysis Project\Covid cases in India.xlsx")

# %%
df
# Out:
#     S. No. Name of State / UT  Total Confirmed cases (Indian National)  \
# 0        1     Andhra Pradesh                                       12
# 1        2       Chhattisgarh                                        6
# 2        3              Delhi                                       38
# 3        4            Gujarat                                       43
# 4        5            Haryana                                       16
# 5        6   Himachal Pradesh                                        4
# 6        7          Karnataka                                       20
# 7        8             Kerala                                      131
# 8        9     Madhya Pradesh                                       23
# 9       10        Maharashtra                                      144
# 10      11             Odisha                                        3
# 11      12         Puducherry                                        1
# ...

# %%
df.drop(['S. No.'],axis=1,inplace=True)

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
df['Total Cases']=df['Total Confirmed cases (Indian National)']+df['Total Confirmed cases ( Foreign National )']

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
total_cases_overall=df['Total Cases'].sum()
print('The total number of cases uptil 21st March 2020 in India is',total_cases_overall)
# Out:
# The total number of cases uptil 21st March 2020 in India is 729

# %%
df['Active cases']=df['Total Cases']-(df['Cured'] + df['Death'])

# %%
df
# Out:
#    Name of State / UT  Total Confirmed cases (Indian National)  \
# 0      Andhra Pradesh                                       12
# 1        Chhattisgarh                                        6
# 2               Delhi                                       38
# 3             Gujarat                                       43
# 4             Haryana                                       16
# 5    Himachal Pradesh                                        4
# 6           Karnataka                                       20
# 7              Kerala                                      131
# 8      Madhya Pradesh                                       23
# 9         Maharashtra                                      144
# 10             Odisha                                        3
# 11         Puducherry                                        1
# 12             Punjab                                       29
# 13          Rajasthan                                       41
# ...

# %%
#For the background style
df.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col1 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col2 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col3 {
#             background-color:  #feeae0;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col4 {
#             background-color:  #fff5f0;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col5 {
#             background-color:  #fee8de;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row0_col6 {
#             background-color:  #fee8dd;
#             color:  #000000;
#         }    #T_4c80002c_87e0_11ea_96ec_0c84dccb25f0row1_col1 {
#             background-color:  #fff0e8;
#             color:  #000000;
# ...

# %%
df.style.background_gradient(cmap='Blues')
# Out:
# <style  type="text/css" >
#     #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col1 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col2 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col3 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col4 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col5 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row0_col6 {
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }    #T_4f2a3080_87e0_11ea_bbcc_0c84dccb25f0row1_col1 {
#             background-color:  #f1f7fd;
#             color:  #000000;
# ...

# %%
Total_Active_Cases=df.groupby('Name of State / UT')['Total Cases'].sum().sort_values(ascending=False).to_frame()

# %%
Total_Active_Cases.style.background_gradient(cmap='Reds')
# Out:
# <style  type="text/css" >
#     #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row0_col0 {
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row1_col0 {
#             background-color:  #840711;
#             color:  #f1f1f1;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row2_col0 {
#             background-color:  #fcaa8d;
#             color:  #000000;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row3_col0 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row4_col0 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row5_col0 {
#             background-color:  #fcaf93;
#             color:  #000000;
#         }    #T_52d9b37a_87e0_11ea_ad70_0c84dccb25f0row6_col0 {
#             background-color:  #fcb89e;
#             color:  #000000;
# ...

# %%
#GRAPHICAL REPRESENTATION

#1.Pandas Visualization

df.plot(kind='bar',x='Name of State / UT',y='Total Cases')
plt.show()
#2.Plotly Visualization

df.iplot(kind='bar',x='Name of State / UT',y='Total Cases')

# %%
df.plot(kind='bar',x='Name of State / UT',y='Total Cases')
plt.show()

# %%
df.iplot(kind='bar',x='Name of State / UT',y='Total Cases')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-e581d077145b> in <module>
#       1
# ----> 2 df.iplot(kind='bar',x='Name of State / UT',y='Total Cases')
#
# F:\tutorials\anacondaa\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'iplot'
